# %% [markdown]
# ### Bidrectional RNN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### So now this RNN can be LSTM Or GRU version of bidirectional RNN this has entrie context of the words from both the ends thus can predict any word missing at the middle
