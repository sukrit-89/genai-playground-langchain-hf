# %% [markdown]
# ## GRU RNN - Gated Recurrent Unit

# %% [markdown]
# This is another variant of LSTM RNN

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
