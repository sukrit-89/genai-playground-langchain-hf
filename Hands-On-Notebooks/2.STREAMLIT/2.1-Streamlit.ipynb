# %% [markdown]
# Introduction to Streamlit

# %% [markdown]
# Streamlit is a open-source app framework for Machine Learning and Data Science projects. It allows you to create beautiful web applications for you machine learning and data science projects with simple python scripts.
