# %% [markdown]
# Object-Oriented Programming (OOPs) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modelling of read world scenarios using classes and objects.

# %% [markdown]
# Classes and Objects
#
# Olass-->A class is a blue print for creating objects. attributes,methods
# Object-->An Object is an instance of a Class. It represents a specific implementation of the class and holds its own data.

# %%
class Fruit:
    pass


'''Here Banana and Apple are the objects of class fruit'''
Banana=Fruit()
Apple=Fruit()

print(type(Banana))
# Out:
# <class '__main__.Fruit'>

# %%
class Bike:
    pass
BMW=Bike()

BMW.tyre=4
print(BMW.tyre)
'''Here tyre is the instance attribute of the object BMW'''
# Out:
# 4
# 'Here tyre is the instance attribute of the object BMW'

# %%
#instrance varibale
class Dog:
    #constructor 
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
#creating objects
dog1=Dog("Tom",4)
print(dog1.name)
print(dog1.age)
# Out:
# Tom
# 4

# %%
#instance method
class Dog:
    #constructor 
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
    def bark(self):
        print(f'{self.name} says bhauu')

dog1=Dog("Buddy",8)
dog1.bark()
# Out:
# Buddy says bhauu

# %%
#Modelling a Bank Account

class BankAccount():
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance
    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited. New balance is {self.balance}")
    def withdraw(self,amount):
        if amount<self.balance:
            self.balance-=amount
            print(f"{amount} is withdrawn. Current balance is {self.balance}")
        else:
            print("balance too low to be withdrawn")
    def get_balance(self):
        return self.balance
    
#creating an account
account=BankAccount("Sukrit",5000)   
print(account.get_balance())     

#deposits
account.deposit(1000)

#withdrawl
account.withdraw(450)
# Out:
# 5000
# 1000 is deposited. New balance is 6000
# 450 is withdrawn. Current balance is 5550
